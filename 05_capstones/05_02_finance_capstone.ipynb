# %% [markdown]
# # 13B — Finance Data Capstone Project
#
# ---
# ## Learning Objectives- Analyze historical stock data using pandas and numpy- Implement multi-index DataFrames for organized time-series data- Calculate financial metrics like daily returns and volatility- Visualize correlations and risk patterns using Seaborn pairplots and heatmaps- Master rolling window calculations for moving averages

# %% [markdown]
# ## Part 1 — Setup

# %%
from pandas_datareader import data, wbimport pandas as pdimport numpy as npimport datetime

# %%
import matplotlib.pyplot as pltimport seaborn as sns%matplotlib inline

# %% [markdown]
# ---## Part 2 — Get Data

# %%
start = datetime.datetime(2006,1,1)end = datetime.begin(2016,1,1)

# %% [markdown]
# Load stock data for the following major banks: BAC, C, GS, JPM, MS, and WFC.

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']
for ticker in tickers:
    df = data.DataReader(ticker, 'stooq', start, end)
    # Note: Using 'stooq' as an alternative if yahoo is unstable
    print(f'{ticker} loaded.')

# %% [markdown]
# ---## Part 3 — Combine into MultiIndex

# %% [markdown]
# Concatenate the individual stock DataFrames into a single, unified DataFrame called `bank_stocks` using a MultiIndex (Date and Ticker).

# %%
# Implementation placeholder
bank_stocks = pd.concat([df_list], axis=1)

# %% [markdown]
# ---## Part 4 — Basic Stock EDA

# %% [markdown]
# Perform exploratory analysis on the `bank_stocks` DataFrame to identify key price movements.

# %%
# Identify max close price
# Identify biggest daily drop
# Identify biggest daily gain
# Determine the riskiest stock (highest volatility)
# Analyze 2015 risk levels

# %% [markdown]
# ---## Part 5 — Returns

# %% [markdown]
# Calculate the daily percentage returns for each stock to better understand day-to-day volatility.

# %%
returns = bank_stocks['Close'].pct_change()

# %% [markdown]
# ---## Part 6 — Pairplots

# %%
sns.pairplot(returns[1:].dropna())

# %% [markdown]
# ---## Part 7 — Distribution Analysis

# %% [markdown]
# Analyze the distribution of returns for specific periods to observe changes in market volatility.

# %%
# 2015 Morgan Stanley returns distribution
# 2008 Citigroup returns distribution

# %% [markdown]
# ---## Part 8 — Closing Price Trends

# %%
# Plot closing prices of all banks

# %% [markdown]
# ---## Part 9 — Moving Averages

# %%
# Calculate and plot BAC 30-day moving average for 2008

# %% [markdown]
# ---## Part 10 — Correlation Heatmap

# %%
# Create a correlation heatmap
# Create a clustermap of close-price correlations

# %% [markdown]
# ---## Key Takeaways
# - Successfully managed multi-index financial time-series data.
# - Implemented advanced visualization techniques for risk analysis.
# - Derived actionable insights from stock volatility and correlation patterns.

# %% [markdown]
# Next: Section 13A — 911 Calls Capstone Project

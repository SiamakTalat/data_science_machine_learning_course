# %% [markdown]
# # Section 07B — Pandas Exercise: Ecommerce Purchases
#
# **Data Science and Machine Learning Course**
#
# ---
#
# ## Learning Goal
#
# Practice real-world Pandas skills using transactional ecommerce data.
#
# Skills reinforced:
# - Exploratory data analysis
# - Filtering and counting
# - String extraction with lambdas
# - Multiple-condition filtering
# - `value_counts()` for frequency analysis
# - Feature extraction from string columns
#
# ---
#
# > **Instructions:** Work through each question independently. Attempt before checking solutions. Add new cells with `Alt + Enter` to preserve the original question structure.

# %% [markdown]
# ---
#
# ## Setup — Load the Dataset

# %%
import pandas as pd

# %%
ecom = pd.read_csv('Ecommerce Purchases')

# %%
ecom.head()

# %% [markdown]
# ---
#
# ## Part 1 — Basic Exploration

# %% [markdown]
# ### Q1. How many rows and columns does the dataset have?

# %%
# Your code here

# %% [markdown]
# ### Q2. What is the average Purchase Price?

# %%
# Your code here

# %% [markdown]
# ### Q3. What are the highest and lowest Purchase Prices?

# %%
# Your code here

# %% [markdown]
# ### Q4. How many people have English (`'en'`) as their language?

# %%
# Your code here

# %% [markdown]
# ### Q5. How many people have the job title `'Lawyer'`?

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 2 — Intermediate Questions

# %% [markdown]
# ### Q6. How many purchases were made in the AM vs PM?

# %%
# Your code here

# %% [markdown]
# ### Q7. What are the 5 most common job titles among purchasers?

# %%
# Your code here

# %% [markdown]
# ### Q8. What was the Purchase Price for the lot `'90 WT'`?

# %%
# Your code here

# %% [markdown]
# ### Q9. What is the email address of the person with credit card number `4926535242672853`?

# %%
# Your code here

# %% [markdown]
# ### Q10. How many people made a purchase with American Express AND spent more than $95?
#
# *Hint: use `&` to combine two conditions.*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 3 — Advanced String Processing

# %% [markdown]
# ### Q11. How many people have a credit card that expires in 2025?
#
# *Hint: the expiry date is stored as a string like `'02/25'` — use `apply()` and a lambda to extract the year portion.*

# %%
# Your code here

# %% [markdown]
# ### Q12. What are the top 5 most common email providers?
#
# *Hint: split each email at `@` and take the second part — the domain.*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Key ideas from this exercise:
#
# - `value_counts()` is a quick way to identify the most frequent categories in any column.
# - String columns can be parsed with `apply()` + lambda — powerful for feature extraction.
# - Multi-condition filtering requires `&` and `|`, not Python's `and` / `or`.
# - Wrapping boolean conditions in parentheses is required: `(cond1) & (cond2)`.
# - Real datasets embed useful information in string fields — expiry years, email domains, etc.
#
# ---
#
# *See **07B_Ecommerce_Solutions.ipynb** for all answers.*

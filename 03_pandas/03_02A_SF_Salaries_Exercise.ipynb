# %% [markdown]
# # Section 07A — Pandas Exercise: SF Salaries
#
# **Data Science and Machine Learning Course**
#
# ---
#
# ## Learning Goal
#
# Strengthen practical Pandas skills using a real-world public salary dataset.
#
# Skills reinforced:
# - Reading CSV files
# - Filtering and conditional selection
# - Aggregation and descriptive statistics
# - Label-based indexing with `.loc[]`
# - `groupby()` with aggregation
# - `apply()` with custom functions
# - Feature engineering and correlation
#
# ---
#
# > **Instructions:** Work through each question independently. Use `Alt + Enter` to add answer cells without overwriting the question cells. Check the solutions notebook only after attempting each question.

# %% [markdown]
# ---
#
# ## Setup — Load the Dataset

# %%
import pandas as pd

# %%
sal = pd.read_csv('Salaries.csv')

# %%
sal.head()

# %% [markdown]
# ---
#
# ## Part 1 — Warm-Up Questions

# %% [markdown]
# ### Q1. How many entries (rows) are in this dataset?

# %%
# Your code here

# %% [markdown]
# ### Q2. What is the average BasePay across all employees?

# %%
# Your code here

# %% [markdown]
# ### Q3. What is the highest OvertimePay recorded?

# %%
# Your code here

# %% [markdown]
# ### Q4. What is the job title of JOSEPH DRISCOLL?

# %%
# Your code here

# %% [markdown]
# ### Q5. How much does JOSEPH DRISCOLL make (TotalPayBenefits)?

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 2 — Intermediate Questions

# %% [markdown]
# ### Q6. Who is the highest paid person (including benefits)?
#
# *Hint: return the full row, not just the name.*

# %%
# Your code here

# %% [markdown]
# ### Q7. Who is the lowest paid person (including benefits)?
#
# *What is strange about this result? Reflect in a markdown cell below.*

# %%
# Your code here

# %% [markdown]
# *Your observation here...*

# %% [markdown]
# ### Q8. What was the average BasePay for each year in the dataset?

# %%
# Your code here

# %% [markdown]
# ### Q9. How many unique job titles exist in the dataset?

# %%
# Your code here

# %% [markdown]
# ### Q10. What are the top 5 most common job titles?

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 3 — Advanced Questions

# %% [markdown]
# ### Q11. In 2013, how many job titles were held by exactly one person?
#
# *Hint: filter by year, use `value_counts()`, then count how many have a count of 1.*

# %%
# Your code here

# %% [markdown]
# ### Q12. How many employees have the word "chief" in their job title?
#
# *Hints:*
# - *Use `apply()` with a custom function*
# - *Convert to lowercase before checking*
# - *Split the title into words to avoid partial matches (e.g., "chieftain")*

# %%
# Your code here

# %% [markdown]
# ### Q13 (Bonus). Is there a correlation between job title length and total pay?
#
# *Hint:*
# - *Create a new column for title character length*
# - *Use `.corr()` on the relevant columns*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Key ideas from this exercise:
#
# - Real datasets often contain anomalies — check your results critically (see Q7).
# - `apply()` with a custom function is essential for string-based feature engineering.
# - `groupby()` combined with a specific column and aggregation is a core workflow.
# - Multiple valid approaches usually exist for the same Pandas question.
# - Feature engineering (title length → correlation) naturally emerges from exploration.
#
# ---
#
# *See **07A_SF_Salaries_Solutions.ipynb** for all answers.*

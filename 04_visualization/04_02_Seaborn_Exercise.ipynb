# %% [markdown]
# # Section 04.02 — Seaborn Exercise
#
# **Data Science and Machine Learning Course**
#
# ---
#
# ## Learning Goal
#
# Practice identifying and recreating common Seaborn plot types using the Titanic dataset.
#
# Skills practiced:
# - Choosing the right plot type for the data and question
# - Selecting the correct columns
# - Reproducing figure structure with minimal code
# - Working with a real-world dataset
#
# ---
#
# > **Instructions:** Write your solution in the empty cell below each task. Attempt each exercise independently before checking `09_Seaborn_Solutions.ipynb`.

# %% [markdown]
# ## Setup

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
titanic = sns.load_dataset('titanic')
titanic.head()

# %% [markdown]
# ---
#
# ## Exercise 1 — Joint Plot
#
# **Task:** Create a joint plot showing:
# - `fare` on the x-axis
# - `age` on the y-axis

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2 — Distribution Plot
#
# **Task:** Create a histogram of the `fare` column:
# - Remove the KDE line
# - Use a red fill color
# - Use 30 bins
#
# *Hint: use `sns.histplot()` with the appropriate arguments.*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3 — Box Plot
#
# **Task:** Create a box plot with:
# - `class` on the x-axis
# - `age` on the y-axis
# - A colorful palette

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4 — Swarm Plot
#
# **Task:** Create a swarm plot with:
# - `class` on the x-axis
# - `age` on the y-axis

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5 — Count Plot
#
# **Task:** Create a count plot showing the frequency of each category in the `sex` column.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6 — Heatmap
#
# **Task:** Create a heatmap of the Titanic dataset correlation matrix:
# - Use a diverging colormap
# - Make the figure large enough to be readable (e.g. 10 × 7)
# - Add a title
#
# *Hint: compute the correlation matrix first with `.corr(numeric_only=True)`, then pass it to `sns.heatmap()`.*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7 — FacetGrid
#
# **Task:** Use a `FacetGrid` to create two panels — one per `sex` value — each showing a distribution of `age`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Think about the following before checking solutions:
#
# - How do you tell a joint plot from a pair plot at a glance?
# - When is a box plot better than a swarm plot?
# - Why does a heatmap only make sense after data has been transformed into matrix form?
# - Which plots are best for quick exploratory analysis of an unfamiliar dataset?
#
# ---
#
# *See **09_Seaborn_Solutions.ipynb** for all answers.*

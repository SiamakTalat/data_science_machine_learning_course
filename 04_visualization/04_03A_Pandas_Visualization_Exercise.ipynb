# %% [markdown]
# # Section 10A — Pandas Built-in Visualization Exercise
#
# **Data Science and Machine Learning Course**
#
# ---
#
# ## Learning Goal
#
# Reinforce quick plotting directly from Pandas DataFrames.
#
# Skills practiced:
# - Plotting directly from DataFrames and Series
# - Selecting the correct plot type for the task
# - Customising size, style, and appearance
# - Applying Matplotlib styling to Pandas plots
#
# ---
#
# > **Instructions:** Work through each exercise before checking `10A_Pandas_Visualization_Solutions.ipynb`.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df3 = pd.read_csv('df3')
df3.head()

# %% [markdown]
# ---
#
# ## Exercise 1 — Scatter Plot
#
# **Task:** Create a scatter plot of column `B` versus column `A`.
#
# Try to match:
# - Figure width of about 12 inches
# - Reasonable point size
# - Red point color
#
# *Hint:* Use `df3.plot.scatter()` with `figsize`, `s`, and `c` arguments.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2 — Histogram
#
# **Task:** Create a histogram of column `A`.
#
# *Hint:* Use the `.plot.hist()` accessor.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3 — Styled Histogram
#
# **Task:** Apply the `ggplot` style sheet and recreate the histogram of column `A` with more bins and some transparency.
#
# *Hint:* Call `plt.style.use('ggplot')` before plotting, and use the `bins` and `alpha` arguments.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4 — Box Plot
#
# **Task:** Create a box plot comparing **only** columns `A` and `B`.
#
# *Hint:* Select the columns first with `df3[['A', 'B']]`, then call `.plot.box()`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5 — KDE Plot
#
# **Task:** Create a KDE (Kernel Density Estimation) plot for column `D`.
#
# *Hint:* Use `.plot.kde()` or `.plot.density()`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6 — Styled KDE Plot
#
# **Task:** Recreate the KDE plot for column `D`, but now:
# - Increase the line width to 3
# - Make the line dashed
#
# *Hint:* Pass `lw=` and `ls=` (or `linestyle=`) arguments to `.plot.kde()`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7 — Area Plot
#
# **Task:** Create an area plot of all columns for only the **first 30 rows** of `df3`.
#
# *Hint:* Use `.iloc[:30]` to slice the DataFrame before plotting.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 8 — Bonus Challenge
#
# **Task:** Recreate the area plot from Exercise 7, but move the legend **outside** the figure to the right.
#
# *Hint:* After the plot call, use `plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Questions to think about:
# - When is Pandas plotting enough by itself?
# - When should you switch to Seaborn?
# - Which plot types are most useful during ML preprocessing?
# - Which built-in plot is most useful for fast feature inspection?
#
# ---
#
# *See **10A_Pandas_Visualization_Solutions.ipynb** for full answers.*
